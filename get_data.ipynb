# %%
import pandas as pd
from tqdm.notebook import tqdm

import requests

from binance.client import Client
from datetime import datetime, timedelta

# %%
url = 'https://api.coingecko.com/api/v3/coins/markets'
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 50,
    'page': 1,
    'sparkline': False
}

response = requests.get(url, params=params)
data = response.json()

top_20_symbols = [coin['symbol'].upper() for coin in data]
top_20_names = [coin['name'] for coin in data]
top_20_caps = [coin['market_cap'] for coin in data]

for i, (name, symbol, cap) in enumerate(zip(top_20_names, top_20_symbols, top_20_caps), 1):
    print(f"{i}. {name} ({symbol}) — ${cap:,.0f}")
# Out:
# 1. Bitcoin (BTC) — $2,162,462,898,555
# 2. Ethereum (ETH) — $322,498,383,113
# 3. Tether (USDT) — $155,520,321,175
# 4. XRP (XRP) — $136,593,001,132
# 5. BNB (BNB) — $96,125,524,948
# 6. Solana (SOL) — $83,093,268,118
# 7. USDC (USDC) — $61,600,716,000
# 8. Dogecoin (DOGE) — $26,947,858,067
# 9. TRON (TRX) — $26,545,240,175
# 10. Lido Staked Ether (STETH) — $24,283,523,065
# 11. Cardano (ADA) — $23,673,794,757
# 12. Hyperliquid (HYPE) — $14,862,212,643
# 13. Wrapped Bitcoin (WBTC) — $13,988,205,890
# 14. Wrapped stETH (WSTETH) — $11,634,556,738
# 15. Sui (SUI) — $10,626,343,060
# 16. Bitcoin Cash (BCH) — $9,356,025,760
# 17. Chainlink (LINK) — $9,289,492,079
# 18. LEO Token (LEO) — $8,508,305,507
# 19. Avalanche (AVAX) — $8,410,035,944
# 20. Stellar (XLM) — $8,384,910,951
# 21. Toncoin (TON) — $7,504,022,293
# 22. WhiteBIT Coin (WBT) — $7,490,165,510
# 23. Shiba Inu (SHIB) — $7,242,138,459
# 24. USDS (USDS) — $7,018,928,620
# 25. Wrapped eETH (WEETH) — $6,990,568,687
# 26. WETH (WETH) — $6,986,109,388
# 27. Hedera (HBAR) — $6,786,650,260
# 28. Litecoin (LTC) — $6,743,209,534
# 29. Binance Bridged USDT (BNB Smart Chain) (BSC-USD) — $6,284,264,316
# 30. Polkadot (DOT) — $6,067,685,245
# 31. Monero (XMR) — $6,061,895,932
# 32. Ethena USDe (USDE) — $5,896,077,485
# 33. Bitget Token (BGB) — $5,374,785,461
# 34. Coinbase Wrapped BTC (CBBTC) — $4,970,838,286
# 35. Pepe (PEPE) — $4,772,046,397
# 36. Uniswap (UNI) — $4,723,080,120
# 37. Pi Network (PI) — $4,425,422,658
# 38. Aave (AAVE) — $4,387,483,809
# 39. Dai (DAI) — $3,595,298,838
# 40. Ethena Staked USDe (SUSDE) — $3,494,968,124
# 41. Bittensor (TAO) — $3,433,773,291
# 42. OKB (OKB) — $3,111,085,898
# 43. Aptos (APT) — $3,108,325,661
# 44. Internet Computer (ICP) — $3,014,902,589
# 45. NEAR Protocol (NEAR) — $2,926,456,031
# 46. BlackRock USD Institutional Digital Liquidity Fund (BUIDL) — $2,904,572,220
# 47. Cronos (CRO) — $2,783,738,514
# 48. Jito Staked SOL (JITOSOL) — $2,711,453,624
# 49. Ethereum Classic (ETC) — $2,665,780,426
# 50. Tokenize Xchange (TKX) — $2,650,849,257

# %%
top_20_symbols = [symbol + 'USDT' for symbol in top_20_symbols]

# %%
api_key='your_api_key'
api_secret='your_api_secret'

client = Client(api_key, api_secret)

# %%
tickers = client.get_ticker()
tickers = pd.DataFrame(tickers)

# %%
tickers = tickers[tickers['symbol'].isin(top_20_symbols)]

# %%
tickers
# Out:
#         symbol    priceChange priceChangePercent weightedAvgPrice  \
# 11     BTCUSDT  3883.93000000              3.706  106907.52972888
# 12     ETHUSDT   159.04000000              6.345    2607.22506406
# 98     BNBUSDT    13.76000000              2.136     654.13172222
# 190    LTCUSDT     3.42000000              4.010      87.38729039
# 296    ADAUSDT     0.03140000              5.031       0.64515213
# 306    XRPUSDT     0.17370000              8.085       2.25519966
# 334    XLMUSDT     0.01250000              4.883       0.26398988
# 350    TRXUSDT     0.00730000              2.680       0.27912056
# 351    ETCUSDT     1.05000000              6.391      17.03737153
# 422   USDCUSDT    -0.00030000             -0.030       0.99970322
# 431   LINKUSDT     1.05000000              8.034      13.65453913
# 455   USDSUSDT     0.00000000                  0       0.00000000
# 475    XMRUSDT     0.00000000                  0       0.00000000
# 558   DOGEUSDT     0.00702000              4.064       0.17708220
# 627   HBARUSDT     0.00843000              5.545       0.15886100
# 661    BCHUSDT     7.70000000              1.670     463.03903666
# 779    SOLUSDT     8.14000000              5.457     155.67393949
# 873    DAIUSDT     0.00000000                  0       0.00000000
# 954    DOTUSDT     0.23000000              6.122       3.90132410
# 1042   UNIUSDT     0.85000000             12.160       7.61007987
# 1052  AVAXUSDT     1.07000000              5.679      19.58029956
# 1092  AAVEUSDT    20.54000000              7.672     285.08676007
# 1097  NEARUSDT     0.19000000              8.688       2.31025618
# 1419  SHIBUSDT     0.00000042              3.538       0.00001214
# 1424   ICPUSDT     0.24600000              4.568       5.62028236
# 2111   APTUSDT     0.38500000              8.628       4.66857980
# 2198  WBTCUSDT  3824.39000000              3.649  106781.35650029
# 2205   SUIUSDT     0.13660000              4.575       3.08931392
# 2213  PEPEUSDT     0.00000039              3.578       0.00001127
# 2590   TAOUSDT    30.70000000              8.552     380.15952117
# 2700   TONUSDT     0.09200000              3.115       3.00292393
#
#        prevClosePrice        lastPrice        lastQty         bidPrice  \
# 11    104800.77000000  108684.69000000     0.00164000  108684.69000000
# 12      2506.40000000    2665.45000000     0.01190000    2665.44000000
# 98       644.29000000     658.05000000     0.10300000     658.04000000
# 190       85.30000000      88.71000000     0.86900000      88.70000000
# 296        0.62420000       0.65550000    15.20000000       0.65550000
# 306        2.14850000       2.32220000   353.10000000       2.32220000
# 334        0.25610000       0.26850000   337.00000000       0.26840000
# 350        0.27240000       0.27970000   407.40000000       0.27960000
# 351       16.43000000      17.48000000     0.85000000      17.47000000
# 422        0.99980000       0.99950000    85.00000000       0.99950000
# 431       13.07000000      14.12000000   868.59000000      14.11000000
# 455        0.00000000       0.00000000     0.00000000       0.00000000
# 475      118.70000000       0.00000000     0.00000000       0.00000000
# 558        0.17272000       0.17974000   560.00000000       0.17973000
# 627        0.15202000       0.16045000  7136.00000000       0.16044000
# 661      461.10000000     468.80000000     2.79200000     468.80000000
# 779      149.16000000     157.31000000    41.14900000     157.31000000
# 873        0.00000000       0.00000000     0.00000000       0.00000000
# 954        3.75700000       3.98700000     2.08000000       3.98600000
# 1042       6.99100000       7.84000000     3.86000000       7.84000000
# 1052      18.85000000      19.91000000    10.00000000      19.91000000
# 1092     267.73000000     288.26000000     1.36700000     288.24000000
# 1097       2.18700000       2.37700000     3.00000000       2.37700000
# 1419       0.00001187       0.00001229     1529187.00       0.00001228
# 1424       5.38200000       5.63100000    78.31000000       5.63100000
# 2111       4.46400000       4.84700000    60.34000000       4.84700000
# 2198  104787.68000000  108629.83000000     0.00012000  108632.66000000
# 2205       2.98560000       3.12210000    12.20000000       3.12210000
# 2213       0.00001089       0.00001129    19317349.00       0.00001129
# 2590     359.00000000     389.70000000     2.58890000     389.60000000
# 2700       2.95200000       3.04500000     5.54000000       3.04400000
#
#                  bidQty         askPrice  ...        openPrice  \
# 11           4.05249000  108684.70000000  ...  104800.76000000
# 12          98.87340000    2665.45000000  ...    2506.41000000
# 98          45.47600000     658.05000000  ...     644.29000000
# 190         24.59600000      88.71000000  ...      85.29000000
# 296     325331.60000000       0.65560000  ...       0.62410000
# 306       4956.70000000       2.32230000  ...       2.14850000
# 334      39574.00000000       0.26850000  ...       0.25600000
# 350     463354.60000000       0.27970000  ...       0.27240000
# 351        557.14000000      17.48000000  ...      16.43000000
# 422   43701174.00000000       0.99960000  ...       0.99980000
# 431       4123.67000000      14.12000000  ...      13.07000000
# 455          0.00000000       0.00000000  ...       0.00000000
# 475          0.00000000       0.00000000  ...       0.00000000
# 558     134746.00000000       0.17974000  ...       0.17272000
# 627       9045.00000000       0.16045000  ...       0.15202000
# 661         12.82100000     468.90000000  ...     461.10000000
# 779        192.00600000     157.32000000  ...     149.17000000
# 873          0.00000000       0.00000000  ...       0.00000000
# 954        755.75000000       3.98700000  ...       3.75700000
# 1042       186.85000000       7.84100000  ...       6.99000000
# 1052      2739.66000000      19.92000000  ...      18.84000000
# 1092         1.64000000     288.25000000  ...     267.72000000
# 1097      8490.30000000       2.37800000  ...       2.18700000
# 1419      2863251595.00       0.00001229  ...       0.00001187
# 1424       108.00000000       5.63200000  ...       5.38500000
# 2111      1133.06000000       4.84800000  ...       4.46200000
# 2198         0.02430000  108632.67000000  ...  104805.44000000
# 2205      2556.10000000       3.12220000  ...       2.98550000
# 2213     17723347047.00       0.00001130  ...       0.00001090
# 2590         9.99910000     389.70000000  ...     359.00000000
# 2700      2768.31000000       3.04500000  ...       2.95300000
#
#             highPrice         lowPrice               volume  \
# 11    108888.00000000  104494.53000000       13761.36464000
# 12      2680.34000000    2497.69000000      565347.77130000
# 98       659.46000000     642.77000000      113901.13400000
# 190       88.92000000      84.92000000      291545.78200000
# 296        0.65750000       0.62090000    83018622.40000000
# 306        2.33700000       2.14080000   155092913.10000000
# 334        0.27040000       0.25550000    50422173.00000000
# 350        0.29530000       0.26920000  1044072390.30000000
# 351       17.53000000      16.35000000      331026.01000000
# 422        0.99990000       0.99940000  1307584857.00000000
# 431       14.17000000      13.01000000     2147066.45000000
# 455        0.00000000       0.00000000           0.00000000
# 475        0.00000000       0.00000000           0.00000000
# 558        0.18115000       0.17194000   804025577.00000000
# 627        0.16335000       0.15131000   129570852.00000000
# 661      476.50000000     450.00000000       82485.14800000
# 779      158.80000000     148.15000000     3254241.42700000
# 873        0.00000000       0.00000000           0.00000000
# 954        3.99100000       3.73500000     3471861.25000000
# 1042       7.98100000       6.96700000    14280458.39000000
# 1052      20.00000000      18.73000000     1711365.68000000
# 1092     295.75000000     266.69000000      220237.89800000
# 1097       2.38700000       2.17200000     8788731.40000000
# 1419       0.00001233       0.00001180     1023344366271.00
# 1424       5.75800000       5.34400000     2327591.66000000
# 2111       4.85200000       4.43900000     2930347.76000000
# 2198  108807.29000000  104500.93000000         120.09886000
# 2205       3.15890000       2.96260000    35851385.10000000
# 2213       0.00001157       0.00001082    19170315977873.00
# 2590     391.80000000     356.60000000       64780.46240000
# 2700       3.04600000       2.93900000     5812092.23000000
#
#               quoteVolume       openTime      closeTime     firstId  \
# 11    1471193499.36074580  1750021487001  1750107887001  5013492610
# 12    1473988879.24279800  1750021487011  1750107887011  2534562870
# 98      74506344.94619000  1750021486081  1750107886081  1078214434
# 190     25477395.91488000  1750021482648  1750107882648   467699436
# 296     53559640.67969000  1750021487248  1750107887248   670194075
# 306    349765484.52287000  1750021485918  1750107885918  1184759342
# 334     13310943.46090000  1750021487103  1750107887103   224701538
# 350    291422074.66767000  1750021487217  1750107887217   364045229
# 351      5639813.11850000  1750021487023  1750107887023   236728425
# 422   1307196791.53640000  1750021487327  1750107887327   281556608
# 431     29317202.86690000  1750021486424  1750107886424   415095467
# 455            0.00000000  1749111029213  1749197429213          -1
# 475            0.00000000  1749111029213  1749197429213          -1
# 558    142378616.71269000  1750021486536  1750107886536  1145447909
# 627     20583754.92039000  1750021486631  1750107886631   191308313
# 661     38193843.46850000  1750021486666  1750107886666   228775711
# 779    506600582.99226000  1750021486707  1750107886707  1340178281
# 873            0.00000000  1749111029213  1749197429213          -1
# 954     13544855.95851000  1750021485882  1750107885882   408503051
# 1042   108675428.85888000  1750021485904  1750107885904   208782981
# 1052    33509052.67750000  1750021487059  1750107887059   377065918
# 1092    62786908.78565000  1750021486002  1750107886002   226456385
# 1097    20304221.04680000  1750021486724  1750107886724   268120380
# 1419    12427673.26744799  1750021486334  1750107886334  1558291550
# 1424    13081722.33744000  1750021486147  1750107886147   192640649
# 2111    13680562.36378000  1750021486500  1750107886500   146839836
# 2198    12824319.18493840  1750021487184  1750107887184    20318647
# 2205   110756183.08017000  1750021487027  1750107887027   351088523
# 2213   216116776.16037996  1750021487001  1750107887001   477580208
# 2590    24626909.56692000  1750021486607  1750107886607    80104412
# 2700    17453270.86725000  1750021486716  1750107886716    62222137
#
#           lastId    count
# 11    5016234532  2741923
# 12    2537590470  3027601
# 98    1078658966   444533
# 190    467912270   212835
# 296    670394879   200805
# 306   1186081001  1321660
# 334    224781799    80262
# 350    364403297   358069
# 351    236768109    39685
# 422    281848187   291580
# 431    415192013    96547
# 455           -1        0
# 475           -1        0
# 558   1146172735   724827
# 627    191459961   151649
# 661    229050866   275156
# 779   1342216245  2037965
# 873           -1        0
# 954    408554329    51279
# 1042   209145038   362058
# 1052   377213928   148011
# 1092   226806225   349841
# 1097   268248640   128261
# 1419  1558549932   258383
# 1424   192732773    92125
# 2111   146901971    62136
# 2198    20333089    14443
# 2205   351476369   387847
# 2213   477992847   412640
# 2590    80238573   134162
# 2700    62297407    75271
#
# [31 rows x 21 columns]

# %%
def get_historical_data(symbol, limit=1000, interval=Client.KLINE_INTERVAL_1DAY, client=client):
    end_date = datetime.now()
    start_date = end_date - timedelta(days=limit)
    start_timestamp = int(start_date.timestamp() * 1000)
    end_timestamp = int(end_date.timestamp() * 1000)

    klines = client.get_historical_klines(symbol, interval, start_str=start_timestamp, end_str=end_timestamp)

    return klines

# %%
column_names = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av', 'ignore']
df = pd.DataFrame(columns=column_names)

for currency in tqdm(tickers['symbol'], desc="Processing currencies"):
    try:
        klines = get_historical_data(currency, 1000)
        currency_df = pd.DataFrame(klines, columns=column_names)
        currency_df['timestamp'] = pd.to_datetime(currency_df['timestamp'], unit='ms')
        currency_df['symbol'] = currency
        df = pd.concat([df, currency_df])
    except Exception as e:
        print(f"Error: {e}")
        continue
# Out:
# Processing currencies:   0%|          | 0/31 [00:00<?, ?it/s]
# /var/folders/7x/q4zhf1wx08z6l2f4bqz5b8dc0000gn/T/ipykernel_97462/4238482622.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, currency_df])

# %%
df
# Out:
#      timestamp            open            high             low  \
# 0   2022-09-21  18874.31000000  19956.00000000  18125.98000000
# 1   2022-09-22  18461.36000000  19550.17000000  18356.39000000
# 2   2022-09-23  19401.63000000  19500.00000000  18531.42000000
# 3   2022-09-24  19288.57000000  19316.14000000  18805.34000000
# 4   2022-09-25  18921.99000000  19180.21000000  18629.20000000
# ..         ...             ...             ...             ...
# 308 2025-06-12      3.23700000      3.24500000      3.06900000
# 309 2025-06-13      3.08700000      3.08800000      2.89800000
# 310 2025-06-14      3.02400000      3.03600000      2.90400000
# 311 2025-06-15      2.95300000      2.98400000      2.93900000
# 312 2025-06-16      2.97400000      3.04600000      2.95300000
#
#               close             volume     close_time             quote_av  \
# 0    18461.36000000    385034.10021000  1663804799999  7338667639.75195680
# 1    19401.63000000    379321.72111000  1663891199999  7203741481.48363670
# 2    19289.91000000    385886.91829000  1663977599999  7330336009.19099840
# 3    18920.50000000    239496.56746000  1664063999999  4568927983.65078460
# 4    18807.38000000    191191.44920000  1664150399999  3625136713.92470430
# ..              ...                ...            ...                  ...
# 308      3.08800000   5928034.38000000  1749772799999    18814762.25120000
# 309      3.02400000  11296324.76000000  1749859199999    33526237.76905000
# 310      2.95200000   4311913.92000000  1749945599999    12784670.30672000
# 311      2.97300000   2964904.26000000  1750031999999     8786997.54009000
# 312      3.04500000   5315967.10000000  1750118399999    15982549.40474000
#
#       trades        tb_base_av          tb_quote_av ignore   symbol
# 0    6907777   190299.47143000  3628361586.91015330      0  BTCUSDT
# 1    6251862   190987.32145000  3627123696.69056920      0  BTCUSDT
# 2    5906265   194842.08772000  3701394516.77361640      0  BTCUSDT
# 3    3907636   120501.30570000  2298979763.30945220      0  BTCUSDT
# 4    3714450    94989.39646000  1801229611.97685890      0  BTCUSDT
# ..       ...               ...                  ...    ...      ...
# 308    71874  2607618.91000000     8284715.71837000      0  TONUSDT
# 309   124791  5423449.24000000    16093177.09533000      0  TONUSDT
# 310    55856  1928832.31000000     5719980.36550000      0  TONUSDT
# 311    45554  1322126.95000000     3918383.94870000      0  TONUSDT
# 312    64790  2723372.82000000     8187735.50805000      0  TONUSDT
#
# [26401 rows x 13 columns]

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp'].min(), df['timestamp'].max()
# Out:
# (Timestamp('2022-09-21 00:00:00'), Timestamp('2025-06-16 00:00:00'))

# %%
df.to_csv('data.csv', index=False)
